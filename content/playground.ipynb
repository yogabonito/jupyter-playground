# %% [markdown]
# # Welcome to the Jupyter Playground! 👋
#
# Here, you can make your first steps with Python – without the need to install anything! Within this environment, you can
#
# - write Python code,
# - execute Python code, and
# - inspect results in an interactive way.
#
# Have fun 😎
